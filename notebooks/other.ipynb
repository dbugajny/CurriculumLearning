# %%
plt.figure(figsize=(50, 30))
plt.subplot(351)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(352)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(353)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(354)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(355)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(356)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(357)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(358)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(359)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')


plt.subplot(3, 5, 10)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')


plt.subplot(3, 5, 11)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(3, 5, 12)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')


plt.subplot(3, 5, 13)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(3, 5, 14)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')

plt.subplot(3, 5, 15)
plt.imshow(x[np.random.randint(len(x))])
plt.grid(None)
plt.axis('off')


plt.show()
